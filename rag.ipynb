# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from google import genai
gemini_client = genai.Client()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, gemini_client)

# %%
assistant.rag("I just discovered the course. Can I join now?")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 assistant.rag("I just discovered the course. Can I join now?")
#
# File /workspaces/LLM_Zoomcamp_2026/rag_helper.py:86, in RAGBase.rag(self, query)
#      83 def rag(self, query):
#      84     '''
#      85     Perform retrieval-augmented generation (RAG) for the given query.'''
# ---> 86     search_results = self.search(query)
#      87     prompt = self.build_prompt(query, search_results)
#      88     answer = self.llm(prompt)
#
# File /workspaces/LLM_Zoomcamp_2026/rag_helper.py:43, in RAGBase.search(self, query, num_results)
#      40 boost_dict={"question": 3.0, "section": 0.5},
#      41 filter_dict={"course": self.course}
# ---> 43 return self.index.search(
#      44     query,
#      45     num_results=num_results,
#      46     boost_dict=boost_dict,
#      47     filter_dict=filter_dict
#      48     )
#
# File /workspaces/LLM_Zoomcamp_2026/.venv/lib/python3.12/site-packages/minsearch/minsearch.py:159, in Index.search(self, query, filter_dict, boost_dict, num_results, output_ids)
#     157 for field, query_vec in query_vecs.items():
#     158     sim = cosine_similarity(query_vec, self.text_matrices[field]).flatten()
# --> 159     boost = boost_dict.get(field, 1)
#     160     scores += sim * boost
#     162 # Apply filters using the Filter object
#
# AttributeError: 'tuple' object has no attribute 'get'
